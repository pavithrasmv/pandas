# %% [markdown]
# <a href="https://colab.research.google.com/github/pavithrasmv/pandas/blob/main/Rename%20and%20inplace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df1=pd.read_excel("/content/pandas_rename_inplace_practice.xlsx")
print(df1)
# Out:
#      Emp_ID       Emp_Name Department  Age  Salary       City
# 0      1001     Employee_1    Finance   53   36025  Bangalore
# 1      1002     Employee_2    Support   31   25635    Chennai
# 2      1003     Employee_3    Finance   54  115533  Hyderabad
# 3      1004     Employee_4         HR   54   40551      Delhi
# 4      1005     Employee_5      Sales   58   61853    Chennai
# ..      ...            ...        ...  ...     ...        ...
# 995    1996   Employee_996         IT   27  113619    Chennai
# 996    1997   Employee_997      Sales   40   59341     Mumbai
# 997    1998   Employee_998         IT   45   40293  Hyderabad
# 998    1999   Employee_999      Sales   47   78715    Chennai
# 999    2000  Employee_1000    Support   37   44174     Mumbai
#
# [1000 rows x 6 columns]

# %%
import pandas as pd
df1=pd.read_excel("/content/pandas_rename_inplace_practice.xlsx")
print(df1.columns)
# Out:
# Index(['Emp_ID', 'Emp_Name', 'Department', 'Age', 'Salary', 'City'], dtype='object')

# %%
#changing single name
import pandas as pd
df1=pd.read_excel("/content/pandas_rename_inplace_practice.xlsx")
d={
    "Emp_Name":"ename"

}
df2=df1.rename(columns=d)
print(df2)
# Out:
#      Emp_ID          ename Department  Age  Salary       City
# 0      1001     Employee_1    Finance   53   36025  Bangalore
# 1      1002     Employee_2    Support   31   25635    Chennai
# 2      1003     Employee_3    Finance   54  115533  Hyderabad
# 3      1004     Employee_4         HR   54   40551      Delhi
# 4      1005     Employee_5      Sales   58   61853    Chennai
# ..      ...            ...        ...  ...     ...        ...
# 995    1996   Employee_996         IT   27  113619    Chennai
# 996    1997   Employee_997      Sales   40   59341     Mumbai
# 997    1998   Employee_998         IT   45   40293  Hyderabad
# 998    1999   Employee_999      Sales   47   78715    Chennai
# 999    2000  Employee_1000    Support   37   44174     Mumbai
#
# [1000 rows x 6 columns]

# %%
import pandas as pd
df1=pd.read_excel("/content/pandas_rename_inplace_practice.xlsx")
d={
    "Department":"dept",
    "Age":"age",
    "Emp_ID":"eId"
}
df2=df1.rename(columns=d,inplace=False)
print(df1)
print(df2)
# Out:
#      Emp_ID       Emp_Name Department  Age  Salary       City
# 0      1001     Employee_1    Finance   53   36025  Bangalore
# 1      1002     Employee_2    Support   31   25635    Chennai
# 2      1003     Employee_3    Finance   54  115533  Hyderabad
# 3      1004     Employee_4         HR   54   40551      Delhi
# 4      1005     Employee_5      Sales   58   61853    Chennai
# ..      ...            ...        ...  ...     ...        ...
# 995    1996   Employee_996         IT   27  113619    Chennai
# 996    1997   Employee_997      Sales   40   59341     Mumbai
# 997    1998   Employee_998         IT   45   40293  Hyderabad
# 998    1999   Employee_999      Sales   47   78715    Chennai
# 999    2000  Employee_1000    Support   37   44174     Mumbai
#
# [1000 rows x 6 columns]
#       eId       Emp_Name     dept  age  Salary       City
# 0    1001     Employee_1  Finance   53   36025  Bangalore
# 1    1002     Employee_2  Support   31   25635    Chennai
# ...

# %%
import pandas as pd
df1=pd.read_excel("/content/pandas_rename_inplace_practice.xlsx")
df1.columns=["Eid","ename","dept","age","salary","city"]
df1.index=range(10,1010)
print(df1)
print(df1.index)
# Out:
#        Eid          ename     dept  age  salary       city
# 10    1001     Employee_1  Finance   53   36025  Bangalore
# 11    1002     Employee_2  Support   31   25635    Chennai
# 12    1003     Employee_3  Finance   54  115533  Hyderabad
# 13    1004     Employee_4       HR   54   40551      Delhi
# 14    1005     Employee_5    Sales   58   61853    Chennai
# ...    ...            ...      ...  ...     ...        ...
# 1005  1996   Employee_996       IT   27  113619    Chennai
# 1006  1997   Employee_997    Sales   40   59341     Mumbai
# 1007  1998   Employee_998       IT   45   40293  Hyderabad
# 1008  1999   Employee_999    Sales   47   78715    Chennai
# 1009  2000  Employee_1000  Support   37   44174     Mumbai
#
# [1000 rows x 6 columns]
# RangeIndex(start=10, stop=1010, step=1)
