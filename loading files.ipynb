# %% [markdown]
# <a href="https://colab.research.google.com/github/pavithrasmv/pandas/blob/main/loading%20files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#loading files using excel
import pandas as pd
import numpy as np
df1=pd.read_excel("/content/Pandas_Series_Analysis_Informative_Data.xlsx")
print(df1)
# Out:
#     Student_ID Student_Name  Maths_Marks  Science_Marks  English_Marks  \
# 0            1         Arun        100.0           73.0           64.0
# 1            2         Bala          NaN           44.0           76.0
# 2            3       Charan          NaN           43.0           90.0
# 3            4        Divya          NaN           93.0           64.0
# 4            5        Eswar          NaN            NaN            NaN
# 5            6        Farah         72.0           80.0            NaN
# 6            7        Gokul          NaN            NaN            NaN
# 7            8       Harini          NaN           76.0            NaN
# 8            9        Imran         85.0           72.0           82.0
# 9           10         Jaya         89.0            NaN            NaN
# 10          11      Karthik          NaN           48.0            NaN
# 11          12      Lavanya          NaN           98.0            NaN
# ...

# %%
#loadinf files using csv
import pandas as pd
df1=pd.read_csv("/content/data.csv")
print(df1)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
#using excel
import pandas as pd
df1=pd.read_excel("/content/Pandas_Series_Analysis_Informative_Data.xlsx")
print(df1)
# Out:
#     Student_ID Student_Name  Maths_Marks  Science_Marks  English_Marks  \
# 0            1         Arun        100.0           73.0           64.0
# 1            2         Bala          NaN           44.0           76.0
# 2            3       Charan          NaN           43.0           90.0
# 3            4        Divya          NaN           93.0           64.0
# 4            5        Eswar          NaN            NaN            NaN
# 5            6        Farah         72.0           80.0            NaN
# 6            7        Gokul          NaN            NaN            NaN
# 7            8       Harini          NaN           76.0            NaN
# 8            9        Imran         85.0           72.0           82.0
# 9           10         Jaya         89.0            NaN            NaN
# 10          11      Karthik          NaN           48.0            NaN
# 11          12      Lavanya          NaN           98.0            NaN
# ...
