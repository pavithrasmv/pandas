# %% [markdown]
# <a href="https://colab.research.google.com/github/pavithrasmv/pandas/blob/main/groupby.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df1=pd.read_excel("/content/groupby_eda_data.xlsx")
print(df1)
# Out:
#       Order_ID Region Sales_Person    Product  Units_Sold  Revenue
# 0            1   East         Hari     Mobile           7    28338
# 1            2   West        Farah   Keyboard           6    12762
# 2            3  North       Chitra     Mobile           5    19785
# 3            4   West        Gokul   Keyboard          11    10016
# 4            5  South        Farah  Headphone          16    16754
# ...        ...    ...          ...        ...         ...      ...
# 1995      1996  North        Farah   Keyboard          20    36914
# 1996      1997   East         Hari     Laptop          17    34573
# 1997      1998  South         Bala   Keyboard           1    32788
# 1998      1999   East        Farah     Laptop          10    40932
# 1999      2000   West         Arun      Mouse          12    57319
#
# [2000 rows x 6 columns]

# %%
#find tot revenue generated in each region
import pandas as pd
df1=pd.read_excel("/content/groupby_eda_data.xlsx")

grouped=df1.groupby("Region")["Revenue"]
result=grouped.sum()
print(result)
# Out:
# Region
# East     16736002
# North    15722117
# South    14741016
# West     13904361
# Name: Revenue, dtype: int64

# %%
import pandas as pd

df1 = pd.read_excel("/content/groupby_eda_data.xlsx")

res = df1.groupby("Product")["Units_Sold"].sum()

print(res)
# Out:
# Product
# Headphone    3304
# Keyboard     3310
# Laptop       3385
# Mobile       3368
# Mouse        3364
# Tablet       3852
# Name: Units_Sold, dtype: int64
