# %% [markdown]
# <a href="https://colab.research.google.com/github/pavithrasmv/pandas/blob/main/pandas%20project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df1=pd.read_csv("/content/spotify-tracks-dataset-detailed.csv")
print(df1.columns)
# Out:
# Index(['track_id', 'artists', 'album_name', 'track_name', 'popularity',
#        'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'track_genre'],
#       dtype='object')

# %%
#Which genre has the most songs?
import pandas as pd
df1=pd.read_csv("/content/spotify-tracks-dataset-detailed.csv")
grouped=df1.groupby("track_genre")
res=grouped.value_counts()
print(res.head(1))
# Out:
# track_genre  track_id                artists           album_name     track_name     popularity  duration_ms  explicit  danceability  energy  key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  valence  tempo    time_signature
# acoustic     00DuOxungwHwVUX2m37P0P  Chord Overstreet  What You Need  What You Need  53          181786       False     0.519         0.264   0    -11.171   1     0.0601       0.918         0.000253          0.237     0.192    140.354  4                 1
# Name: count, dtype: int64

# %%
import pandas as pd
df1=pd.read_csv("/content/spotify-tracks-dataset-detailed.csv")
top_artist = df1["artists"].value_counts().idxmax()
song_count = df1["artists"].value_counts().max()

print("Artist:", top_artist)
print("Number of Songs:", song_count)
# Out:
# Artist: The Beatles
# Number of Songs: 279

# %%
import pandas as pd
df1=pd.read_csv("/content/spotify-tracks-dataset-detailed.csv")
d={
    "popularity":max
}
grouped=df1.groupby("popularity")
res=grouped.agg(d)
print(res)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1553/3746965373.py in <cell line: 0>()
#       5 }
#       6 grouped=df1.groupby("popularity").mean
# ----> 7 res=grouped.agg(d)
#       8 print(res)
#
# AttributeError: 'function' object has no attribute 'agg'
