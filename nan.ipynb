# %% [markdown]
# <a href="https://colab.research.google.com/github/pavithrasmv/pandas/blob/main/nan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
values=[20,np.nan,40,50]
s=pd.Series(values)
print(s)
# Out:
# 0    20.0
# 1     NaN
# 2    40.0
# 3    50.0
# dtype: float64
